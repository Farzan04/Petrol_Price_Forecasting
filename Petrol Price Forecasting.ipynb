# %% [markdown]
# ##  Petrol Price Forecasting  using Tensor Flow

# %% [markdown]
# ![fuel-price-india-1.webp](data:image/webp;base64,...)

# %% [markdown]
# ## Petrol Prices are going up continously these days and it has become very hard to predict what will be the price range in the next few months or even days.
#
# ### In this project we will try to forecast the different petrol prices for the upcoming dates given to us.
#
# ### We will use LSTM and ARIMA forecasting models to predict the prices.

# %% [markdown]
# **Importing Libraries**

# %%
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib 

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
df1 = pd.read_csv("train_data.csv")
df1.head()
# Out:
#         Date  Petrol (USD)
# 0   6/9/2003         74.59
# 1  6/16/2003         74.47
# 2  6/23/2003         74.42
# 3  6/30/2003         74.35
# 4   7/7/2003         74.28

# %% [markdown]
# **Data Analysis and splitting the data**

# %%
df1.head()
df1.isnull().sum()
# Out:
# Date            0
# Petrol (USD)    2
# dtype: int64

# %%
df2 = df1.dropna()

# %%
df2.rename(columns={"Petrol (USD)": "Petrol"}, inplace = True)
df2.head()
# Out:
# C:\Users\Farzan Nawaz\AppData\Local\Temp\ipykernel_8628\2446066184.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.rename(columns={"Petrol (USD)": "Petrol"}, inplace = True)
#         Date  Petrol
# 0   6/9/2003   74.59
# 1  6/16/2003   74.47
# 2  6/23/2003   74.42
# 3  6/30/2003   74.35
# 4   7/7/2003   74.28

# %%
plt.scatter(df2.Date, df2.Petrol,color='red',label='Prices', s=50)

# %%
df3=df2[df2.Petrol<160]
plt.scatter(df3.Date, df3.Petrol,color='blue',label='Prices', s=50)

# %%
df4=df3.reset_index()['Petrol']
df4.head()
# Out:
# 0    74.59
# 1    74.47
# 2    74.42
# 3    74.35
# 4    74.28
# Name: Petrol, dtype: float64

# %%
scaler=MinMaxScaler(feature_range=(0,1))
df4=scaler.fit_transform(np.array(df4).reshape(-1,1))

# %%
df4
# Out:
# array([[0.00559152],
#        [0.00382578],
#        [0.00309005],
#        [0.00206004],
#        [0.00103002],
#        [0.        ],
#        [0.0126545 ],
#        [0.01309594],
#        [0.01339023],
#        [0.01809888],
#        [0.02354326],
#        [0.02707475],
#        [0.02825191],
#        [0.02972337],
#        [0.02928193],
#        [0.0285462 ],
#        [0.02751619],
#        [0.03266627],
#        [0.02486757],
#        [0.02707475],
#        [0.02633902],
#        [0.02633902],
#        [0.02545615],
#        [0.02530901],
#        [0.02663331],
#        [0.02633902],
#        [0.02589759],
#        [0.02575044],
#        [0.02516186],
#        [0.02545615],
#        [0.02457328],
#        [0.02486757],
#        [0.03163626],
#        [0.03281342],
#        [0.033402  ],
#        [0.03369629],
#        [0.03281342],
#        [0.03193055],
#        [0.03104768],
#        [0.03708064],
#        [0.04679223],
#        [0.04752796],
#        [0.04973514],
#        [0.05370806],
#        [0.05400235],
#        [0.05635668],
#        [0.06165391],
#        [0.07460271],
#        [0.08961154],
#        [0.10712184],
#        [0.11653914],
#        [0.11977634],
#        [0.12110065],
#        [0.10785756],
#        [0.10050029],
#        [0.09123014],
#        [0.08328428],
#        [0.09020012],
#        [0.09755739],
#        [0.09799882],
#        [0.09785168],
#        [0.10256033],
#        [0.10359035],
#        [0.10741613],
#        [0.10771042],
#        [0.10535609],
#        [0.10447322],
#        [0.10403178],
#        [0.10918187],
#        [0.11536198],
#        [0.13095939],
#        [0.13449088],
#        [0.14317245],
#        [0.14802825],
#        [0.14905827],
#        [0.14788111],
#        [0.1066804 ],
#        [0.1465568 ],
#        [0.1449382 ],
#        [0.1066804 ],
#        [0.10285462],
#        [0.10241318],
#        [0.08284285],
#        [0.06945262],
#        [0.06945262],
#        [0.07842849],
#        [0.08284285],
#        [0.08563861],
#        [0.08740436],
#        [0.09181872],
#        [0.10226604],
#        [0.10932902],
#        [0.12492643],
#        [0.1352266 ],
#        [0.14273102],
#        [0.16774573],
#        [0.16804002],
#        [0.16627428],
#        [0.16524426],
#        [0.1640671 ],
#        [0.16274279],
#        [0.15538552],
#        [0.14670394],
#        [0.14420247],
#        [0.15862272],
#        [0.16642142],
#        [0.18422602],
#        [0.19540906],
#        [0.19894055],
#        [0.21100647],
#        [0.21762802],
#        [0.22130665],
#        [0.22748676],
#        [0.2405827 ],
#        [0.24367275],
#        [0.2532372 ],
#        [0.29664509],
#        [0.30694526],
#        [0.29723367],
#        [0.28134197],
#        [0.28399058],
#        [0.29487934],
#        [0.29326074],
#        [0.283402  ],
#        [0.26868746],
#        [0.24014126],
#        [0.21188935],
#        [0.19334903],
#        [0.19334903],
#        [0.19114185],
#        [0.19643908],
#        [0.20114773],
#        [0.20335491],
#        [0.21115362],
#        [0.21777516],
#        [0.22572101],
#        [0.23057681],
#        [0.22836963],
#        [0.22719247],
#        [0.22645674],
#        [0.2230724 ],
#        [0.22572101],
#        [0.23513832],
#        [0.24941142],
#        [0.25853443],
#        [0.27310182],
#        [0.29458505],
#        [0.31106533],
#        [0.32254267],
#        [0.32739847],
#        [0.32636845],
#        [0.32210124],
#        [0.31121248],
#        [0.30944673],
#        [0.31312537],
#        [0.31238964],
#        [0.30547381],
#        [0.30988817],
#        [0.31606828],
#        [0.33357858],
#        [0.34682166],
#        [0.34755739],
#        [0.35079459],
#        [0.34741024],
#        [0.316804  ],
#        [0.29708652],
#        [0.27472042],
#        [0.25412007],
#        [0.22910536],
#        [0.20585639],
#        [0.18746321],
#        [0.18231313],
#        [0.17216009],
#        [0.16965862],
#        [0.16759859],
#        [0.16671572],
#        [0.16597999],
#        [0.1656857 ],
#        [0.16553855],
#        [0.19467334],
#        [0.19849912],
#        [0.20144202],
#        [0.2007063 ],
#        [0.19791054],
#        [0.18967039],
#        [0.17760447],
#        [0.16848146],
#        [0.16789288],
#        [0.17525015],
#        [0.18231313],
#        [0.18922896],
#        [0.1990877 ],
#        [0.20997646],
#        [0.216598  ],
#        [0.22233667],
#        [0.23925839],
#        [0.24970571],
#        [0.26162448],
#        [0.27545615],
#        [0.28310771],
#        [0.29752796],
#        [0.30694526],
#        [0.31636257],
#        [0.32298411],
#        [0.3281342 ],
#        [0.32960565],
#        [0.32886992],
#        [0.32857563],
#        [0.32592702],
#        [0.32357269],
#        [0.32371984],
#        [0.32401413],
#        [0.32357269],
#        [0.32283696],
#        [0.32062978],
#        [0.31047675],
#        [0.30591524],
#        [0.30297234],
#        [0.30047087],
#        [0.30076516],
#        [0.30459094],
#        [0.32636845],
#        [0.33740436],
#        [0.33814008],
#        [0.3472631 ],
#        [0.35388464],
#        [0.37007063],
#        [0.39037669],
#        [0.4011183 ],
#        [0.4108299 ],
#        [0.41745144],
#        [0.41877575],
#        [0.41774573],
#        [0.41671572],
#        [0.41862861],
#        [0.42907593],
#        [0.43569747],
#        [0.44158328],
#        [0.44158328],
#        [0.43878752],
#        [0.43349029],
#        [0.43393172],
#        [0.44791054],
#        [0.45659211],
#        [0.46718658],
#        [0.47380812],
#        [0.48101825],
#        [0.48396115],
#        [0.48602119],
#        [0.49146557],
#        [0.50559152],
#        [0.51927604],
#        [0.53104768],
#        [0.54193643],
#        [0.57018835],
#        [0.59711595],
#        [0.61536198],
#        [0.62757504],
#        [0.63978811],
#        [0.65082401],
#        [0.65670983],
#        [0.66318423],
#        [0.66553855],
#        [0.66494997],
#        [0.62831077],
#        [0.60108888],
#        [0.5843143 ],
#        [0.55929959],
#        [0.55635668],
#        [0.5590053 ],
#        [0.56415539],
#        [0.5635668 ],
#        [0.53855209],
#        [0.52442613],
#        [0.51854032],
#        [0.48307828],
#        [0.41862861],
#        [0.35918187],
#        [0.34123014],
#        [0.31901118],
#        [0.30341377],
#        [0.27339612],
#        [0.25397293],
#        [0.23469688],
#        [0.21865803],
#        [0.20306062],
#        [0.19320188],
#        [0.16494997],
#        [0.17377869],
#        [0.17628016],
#        [0.19437905],
#        [0.2052678 ],
#        [0.22174809],
#        [0.2341083 ],
#        [0.23719835],
#        [0.23646263],
#        [0.23454974],
#        [0.23469688],
#        [0.23469688],
#        [0.25220718],
#        [0.28708064],
#        [0.29281931],
#        [0.30032372],
#        [0.30782813],
#        [0.31474397],
#        [0.32931136],
#        [0.34329017],
#        [0.36330194],
#        [0.37051207],
#        [0.38816951],
#        [0.40862272],
#        [0.42083579],
#        [0.42804591],
#        [0.43201883],
#        [0.42039435],
#        [0.41215421],
#        [0.41141848],
#        [0.41421424],
#        [0.42377869],
#        [0.4377575 ],
#        [0.44864626],
#        [0.45467922],
#        [0.48028252],
#        [0.47410241],
#        [0.46718658],
#        [0.45953502],
#        [0.45114773],
#        [0.44879341],
#        [0.45423779],
#        [0.47895821],
#        [0.48881695],
#        [0.49867569],
#        [0.50426722],
#        [0.50794585],
#        [0.50882872],
#        [0.50662154],
#        [0.50456151],
#        [0.48940553],
#        [0.4889641 ],
#        [0.51692172],
#        [0.53722778],
#        [0.55017657],
#        [0.5541495 ],
#        [0.55473808],
#        [0.55532666],
#        [0.55444379],
#        [0.54958799],
#        [0.5622425 ],
#        [0.58122425],
#        [0.60697469],
#        [0.62360212],
#        [0.63375515],
#        [0.66333137],
#        [0.67289582],
#        [0.68187169],
#        [0.68834609],
#        [0.69114185],
#        [0.69305474],
#        [0.69290759],
#        [0.67274868],
#        [0.65229547],
#        [0.64729253],
#        [0.64243673],
#        [0.64140671],
#        [0.64258387],
#        [0.64302531],
#        [0.63537375],
#        [0.6274279 ],
#        [0.62389641],
#        [0.62242496],
#        [0.62007063],
#        [0.61992348],
#        [0.60962331],
#        [0.59991171],
#        [0.59417304],
#        [0.59520306],
#        [0.60108888],
#        [0.60594467],
#        [0.61506769],
#        [0.62639788],
#        [0.63375515],
#        [0.64052384],
#        [0.64699823],
#        [0.65420836],
#        [0.65612125],
#        [0.65891701],
#        [0.66215421],
#        [0.68172454],
#        [0.69849912],
#        [0.70776928],
#        [0.7243967 ],
#        [0.7451442 ],
#        [0.78266627],
#        [0.78958211],
#        [0.79664509],
#        [0.79958799],
#        [0.8009123 ],
#        [0.80223661],
#        [0.80503237],
#        [0.816804  ],
#        [0.83975868],
#        [0.85300177],
#        [0.86668629],
#        [0.85682755],
#        [0.86227192],
#        [0.87507357],
#        [0.89537964],
#        [0.90361978],
#        [0.91347852],
#        [0.92466157],
#        [0.91509712],
#        [0.9108299 ],
#        [0.90288405],
#        [0.90361978],
#        [0.90715127],
#        [0.90965274],
#        [0.89243673],
#        [0.87139494],
#        [0.88243084],
#        [0.89405533],
#        [0.90420836],
#        [0.91024132],
#        [0.91597999],
#        [0.90847557],
#        [0.88802237],
#        [0.88449088],
#        [0.88890524],
#        [0.89449676],
#        [0.90038258],
#        [0.90406121],
#        [0.89479105],
#        [0.88669806],
#        [0.88699235],
#        [0.88949382],
#        [0.89052384],
#        [0.88581519],
#        [0.87507357],
#        [0.87065921],
#        [0.86756916],
#        [0.86183049],
#        [0.85815185],
#        [0.85756327],
#        [0.85638611],
#        [0.85623896],
#        [0.86035903],
#        [0.8693349 ],
#        [0.87566215],
#        [0.88125368],
#        [0.88346086],
#        [0.89302531],
#        [0.89758682],
#        [0.91230135],
#        [0.9283402 ],
#        [0.93716892],
#        [0.95276633],
#        [0.96041789],
#        [0.98263685],
#        [0.99705709],
#        [1.        ],
#        [0.99396704],
#        [0.98278399],
#        [0.97012949],
#        [0.94290759],
#        [0.90582696],
#        [0.8852266 ],
#        [0.8806651 ],
#        [0.87492643],
#        [0.850206  ],
#        [0.84373161],
#        [0.82828134],
#        [0.83652148],
#        [0.84284873],
#        [0.8534432 ],
#        [0.86183049],
#        [0.87080636],
#        [0.88375515],
#        [0.90509123],
#        [0.92539729],
#        [0.93908181],
#        [0.95203061],
#        [0.95953502],
#        [0.96130077],
#        [0.94496763],
#        [0.94217187],
#        [0.94379046],
#        [0.94290759],
#        [0.92363155],
#        [0.91553855],
#        [0.89582107],
#        [0.88802237],
#        [0.88537375],
#        [0.86580341],
#        [0.85844614],
#        [0.85005886],
#        [0.84961742],
#        [0.84917599],
#        [0.84829311],
#        [0.85035315],
#        [0.8534432 ],
#        [0.86433196],
#        [0.88537375],
#        [0.9027369 ],
#        [0.9218658 ],
#        [0.94599765],
#        [0.96027075],
#        [0.96806945],
#        [0.93246027],
#        [0.92525015],
#        [0.9283402 ],
#        [0.92848735],
#        [0.92554444],
#        [0.90450265],
#        [0.88949382],
#        [0.87124779],
#        [0.86683343],
#        [0.86756916],
#        [0.87448499],
#        [0.88037081],
#        [0.88419659],
#        [0.88655091],
#        [0.88743378],
#        [0.87154208],
#        [0.87639788],
#        [0.89376104],
#        [0.90979988],
#        [0.92201295],
#        [0.92422013],
#        [0.92583873],
#        [0.92392584],
#        [0.92142437],
#        [0.92598587],
#        [0.93275456],
#        [0.93084167],
#        [0.92319011],
#        [0.8709535 ],
#        [0.84476162],
#        [0.84549735],
#        [0.84343732],
#        [0.84181872],
#        [0.81974691],
#        [0.81665686],
#        [0.81930547],
#        [0.82136551],
#        [0.82460271],
#        [0.83210712],
#        [0.83505003],
#        [0.8216598 ],
#        [0.82136551],
#        [0.82474985],
#        [0.82622131],
#        [0.81165391],
#        [0.80650383],
#        [0.80400235],
#        [0.80341377],
#        [0.80856386],
#        [0.80915244],
#        [0.81150677],
#        [0.8119482 ],
#        [0.80267805],
#        [0.79988228],
#        [0.80267805],
#        [0.80194232],
#        [0.80459094],
#        [0.80782813],
#        [0.80753384],
#        [0.81018246],
#        [0.8135668 ],
#        [0.81238964],
#        [0.81371395],
#        [0.81547969],
#        [0.81636257],
#        [0.81915833],
#        [0.82298411],
#        [0.8310771 ],
#        [0.83711006],
#        [0.83725721],
#        [0.83622719],
#        [0.83313714],
#        [0.81547969],
#        [0.8122425 ],
#        [0.81047675],
#        [0.79649794],
#        [0.79164214],
#        [0.79649794],
#        [0.79782225],
#        [0.80061801],
#        [0.80017657],
#        [0.77354326],
#        [0.76942319],
#        [0.7532372 ],
#        [0.74896998],
#        [0.73175397],
#        [0.71703943],
#        [0.71056504],
#        [0.70747499],
#        [0.69114185],
#        [0.67127722],
#        [0.6193349 ],
#        [0.58048852],
#        [0.57313125],
#        [0.54223072],
#        [0.51000589],
#        [0.47998823],
#        [0.47248381],
#        [0.46836374],
#        [0.47292525],
#        [0.48631548],
#        [0.50220718],
#        [0.51486168],
#        [0.52766333],
#        [0.54193643],
#        [0.5509123 ],
#        [0.55694526],
#        [0.56150677],
#        [0.56371395],
#        [0.56886404],
#        [0.57886992],
#        [0.58946439],
#        [0.60167746],
#        [0.61109476],
#        [0.61521483],
#        [0.61683343],
#        [0.61874632],
#        [0.62065921],
#        [0.62374926],
#        [0.62301354],
#        [0.61992348],
#        [0.6209535 ],
#        [0.62654503],
#        [0.62139494],
#        [0.61668629],
#        [0.60726898],
#        [0.5940259 ],
#        [0.57416127],
#        [0.5444379 ],
#        [0.5398764 ],
#        [0.53546204],
#        [0.53560918],
#        [0.51883461],
#        [0.5110359 ],
#        [0.51147734],
#        [0.51206592],
#        [0.49779282],
#        [0.48557975],
#        [0.48454974],
#        [0.48778693],
#        [0.48675692],
#        [0.48204826],
#        [0.47881107],
#        [0.43834609],
#        [0.41377281],
#        [0.41053561],
#        [0.40891701],
#        [0.40729841],
#        [0.4059741 ],
#        [0.40038258],
#        [0.39949971],
#        [0.40170689],
#        [0.40082401],
#        [0.39994114],
#        [0.40038258],
#        [0.40097116],
#        [0.40464979],
#        [0.41745144],
#        [0.42951736],
#        [0.4458505 ],
#        [0.45879929],
#        [0.47380812],
#        [0.48454974],
#        [0.49455562],
#        [0.5       ],
#        [0.50500294],
#        [0.51368452],
#        [0.52354326],
#        [0.53251913],
#        [0.54178929],
#        [0.54458505],
#        [0.54782225],
#        [0.5509123 ],
#        [0.55444379],
#        [0.55488523],
#        [0.55150088],
#        [0.54208358],
#        [0.52295468],
#        [0.51603885],
#        [0.52118893],
#        [0.53296057],
#        [0.54090642],
#        [0.54590936],
#        [0.54561507],
#        [0.54664509],
#        [0.5509123 ],
#        [0.56121248],
#        [0.58137139],
#        [0.60314891],
#        [0.61521483],
#        [0.62316068],
#        [0.62227781],
#        [0.59593879],
#        [0.58137139],
#        [0.58048852],
#        [0.58887581],
#        [0.600206  ],
#        [0.60682755],
#        [0.62963508],
#        [0.64405533],
#        [0.65361978],
#        [0.66539141],
#        [0.67392584],
#        [0.67642731],
#        [0.67598587],
#        [0.6767216 ],
#        [0.67554444],
#        [0.67407298],
#        [0.67083579],
#        [0.65832843],
#        [0.64479105],
#        [0.62860506],
#        [0.62992937],
#        [0.63758093],
#        [0.6465568 ],
#        [0.64552678],
#        [0.63051795],
#        [0.60903473],
#        [0.61006474],
#        [0.61183049],
#        [0.61227192],
#        [0.61035903],
#        [0.60197175],
#        [0.59181872],
#        [0.58166569],
#        [0.57931136],
#        [0.58387287],
#        [0.58534432],
#        [0.58784579],
#        [0.59696881],
#        [0.60800471],
#        [0.61550912],
#        [0.62080636],
#        [0.62889935],
#        [0.64640965],
#        [0.65685697],
#        [0.65715127],
#        [0.64626251],
#        [0.63198941],
#        [0.62978222],
#        [0.63022366],
#        [0.63051795],
#        [0.63802237],
#        [0.65773985],
#        [0.6689229 ],
#        [0.67569158],
#        [0.67010006],
#        [0.67245438],
#        [0.6734844 ],
#        [0.67377869],
#        [0.67657446],
#        [0.68143025],
#        [0.68790465],
#        [0.6958505 ],
#        [0.69864626],
#        [0.69923484],
#        [0.69702766],
#        [0.68143025],
#        [0.66715715],
#        [0.66333137],
#        [0.66068275],
#        [0.66156563],
#        [0.6624485 ],
#        [0.66539141],
#        [0.67319011],
#        [0.68201883],
#        [0.69496763],
#        [0.70644497],
#        [0.72189523],
#        [0.7373455 ],
#        [0.7610359 ],
#        [0.78531489],
#        [0.79782225],
#        [0.80047087],
#        [0.79031783],
#        [0.77942908],
#        [0.77001177],
#        [0.77633902],
#        [0.78369629],
#        [0.78413773],
#        [0.78472631],
#        [0.79178929],
#        [0.79723367],
#        [0.80311948],
#        [0.80885815],
#        [0.81739258],
#        [0.82445556],
#        [0.82960565],
#        [0.82960565],
#        [0.82062978],
#        [0.82313125],
#        [0.83284285],
#        [0.83534432],
#        [0.83034138],
#        [0.82254267],
#        [0.80532666],
#        [0.78266627],
#        [0.75868158],
#        [0.73705121],
#        [0.70865215],
#        [0.68878752],
#        [0.68275456],
#        [0.67642731]])

# %%
training_size=int(len(df4)*0.65)
test_size=len(df4)-training_size
train_data,test_data=df4[0:training_size,:],df4[training_size:len(df4),:1]

# %%
train_data.shape
test_data.shape
# Out:
# (284, 1)

# %% [markdown]
# **Data Preprocessing**

# %%
 import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100 
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return numpy.array(dataX), numpy.array(dataY)

# %%
# reshape into X=t,t+1,t+2,t+3 and Y=t+4
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
X_train
# Out:
# array([[0.00559152, 0.00382578, 0.00309005, ..., 0.16627428, 0.16524426,
#         0.1640671 ],
#        [0.00382578, 0.00309005, 0.00206004, ..., 0.16524426, 0.1640671 ,
#         0.16274279],
#        [0.00309005, 0.00206004, 0.00103002, ..., 0.1640671 , 0.16274279,
#         0.15538552],
#        ...,
#        [0.91024132, 0.91597999, 0.90847557, ..., 0.88419659, 0.88655091,
#         0.88743378],
#        [0.91597999, 0.90847557, 0.88802237, ..., 0.88655091, 0.88743378,
#         0.87154208],
#        [0.90847557, 0.88802237, 0.88449088, ..., 0.88743378, 0.87154208,
#         0.87639788]])

# %%
y_train
# Out:
# array([0.16274279, 0.15538552, 0.14670394, 0.14420247, 0.15862272,
#        0.16642142, 0.18422602, 0.19540906, 0.19894055, 0.21100647,
#        0.21762802, 0.22130665, 0.22748676, 0.2405827 , 0.24367275,
#        0.2532372 , 0.29664509, 0.30694526, 0.29723367, 0.28134197,
#        0.28399058, 0.29487934, 0.29326074, 0.283402  , 0.26868746,
#        0.24014126, 0.21188935, 0.19334903, 0.19334903, 0.19114185,
#        0.19643908, 0.20114773, 0.20335491, 0.21115362, 0.21777516,
#        0.22572101, 0.23057681, 0.22836963, 0.22719247, 0.22645674,
#        0.2230724 , 0.22572101, 0.23513832, 0.24941142, 0.25853443,
#        0.27310182, 0.29458505, 0.31106533, 0.32254267, 0.32739847,
#        0.32636845, 0.32210124, 0.31121248, 0.30944673, 0.31312537,
#        0.31238964, 0.30547381, 0.30988817, 0.31606828, 0.33357858,
#        0.34682166, 0.34755739, 0.35079459, 0.34741024, 0.316804  ,
#        0.29708652, 0.27472042, 0.25412007, 0.22910536, 0.20585639,
#        0.18746321, 0.18231313, 0.17216009, 0.16965862, 0.16759859,
#        0.16671572, 0.16597999, 0.1656857 , 0.16553855, 0.19467334,
#        0.19849912, 0.20144202, 0.2007063 , 0.19791054, 0.18967039,
#        0.17760447, 0.16848146, 0.16789288, 0.17525015, 0.18231313,
#        0.18922896, 0.1990877 , 0.20997646, 0.216598  , 0.22233667,
#        0.23925839, 0.24970571, 0.26162448, 0.27545615, 0.28310771,
#        0.29752796, 0.30694526, 0.31636257, 0.32298411, 0.3281342 ,
#        0.32960565, 0.32886992, 0.32857563, 0.32592702, 0.32357269,
#        0.32371984, 0.32401413, 0.32357269, 0.32283696, 0.32062978,
#        0.31047675, 0.30591524, 0.30297234, 0.30047087, 0.30076516,
#        0.30459094, 0.32636845, 0.33740436, 0.33814008, 0.3472631 ,
#        0.35388464, 0.37007063, 0.39037669, 0.4011183 , 0.4108299 ,
#        0.41745144, 0.41877575, 0.41774573, 0.41671572, 0.41862861,
#        0.42907593, 0.43569747, 0.44158328, 0.44158328, 0.43878752,
#        0.43349029, 0.43393172, 0.44791054, 0.45659211, 0.46718658,
#        0.47380812, 0.48101825, 0.48396115, 0.48602119, 0.49146557,
#        0.50559152, 0.51927604, 0.53104768, 0.54193643, 0.57018835,
#        0.59711595, 0.61536198, 0.62757504, 0.63978811, 0.65082401,
#        0.65670983, 0.66318423, 0.66553855, 0.66494997, 0.62831077,
#        0.60108888, 0.5843143 , 0.55929959, 0.55635668, 0.5590053 ,
#        0.56415539, 0.5635668 , 0.53855209, 0.52442613, 0.51854032,
#        0.48307828, 0.41862861, 0.35918187, 0.34123014, 0.31901118,
#        0.30341377, 0.27339612, 0.25397293, 0.23469688, 0.21865803,
#        0.20306062, 0.19320188, 0.16494997, 0.17377869, 0.17628016,
#        0.19437905, 0.2052678 , 0.22174809, 0.2341083 , 0.23719835,
#        0.23646263, 0.23454974, 0.23469688, 0.23469688, 0.25220718,
#        0.28708064, 0.29281931, 0.30032372, 0.30782813, 0.31474397,
#        0.32931136, 0.34329017, 0.36330194, 0.37051207, 0.38816951,
#        0.40862272, 0.42083579, 0.42804591, 0.43201883, 0.42039435,
#        0.41215421, 0.41141848, 0.41421424, 0.42377869, 0.4377575 ,
#        0.44864626, 0.45467922, 0.48028252, 0.47410241, 0.46718658,
#        0.45953502, 0.45114773, 0.44879341, 0.45423779, 0.47895821,
#        0.48881695, 0.49867569, 0.50426722, 0.50794585, 0.50882872,
#        0.50662154, 0.50456151, 0.48940553, 0.4889641 , 0.51692172,
#        0.53722778, 0.55017657, 0.5541495 , 0.55473808, 0.55532666,
#        0.55444379, 0.54958799, 0.5622425 , 0.58122425, 0.60697469,
#        0.62360212, 0.63375515, 0.66333137, 0.67289582, 0.68187169,
#        0.68834609, 0.69114185, 0.69305474, 0.69290759, 0.67274868,
#        0.65229547, 0.64729253, 0.64243673, 0.64140671, 0.64258387,
#        0.64302531, 0.63537375, 0.6274279 , 0.62389641, 0.62242496,
#        0.62007063, 0.61992348, 0.60962331, 0.59991171, 0.59417304,
#        0.59520306, 0.60108888, 0.60594467, 0.61506769, 0.62639788,
#        0.63375515, 0.64052384, 0.64699823, 0.65420836, 0.65612125,
#        0.65891701, 0.66215421, 0.68172454, 0.69849912, 0.70776928,
#        0.7243967 , 0.7451442 , 0.78266627, 0.78958211, 0.79664509,
#        0.79958799, 0.8009123 , 0.80223661, 0.80503237, 0.816804  ,
#        0.83975868, 0.85300177, 0.86668629, 0.85682755, 0.86227192,
#        0.87507357, 0.89537964, 0.90361978, 0.91347852, 0.92466157,
#        0.91509712, 0.9108299 , 0.90288405, 0.90361978, 0.90715127,
#        0.90965274, 0.89243673, 0.87139494, 0.88243084, 0.89405533,
#        0.90420836, 0.91024132, 0.91597999, 0.90847557, 0.88802237,
#        0.88449088, 0.88890524, 0.89449676, 0.90038258, 0.90406121,
#        0.89479105, 0.88669806, 0.88699235, 0.88949382, 0.89052384,
#        0.88581519, 0.87507357, 0.87065921, 0.86756916, 0.86183049,
#        0.85815185, 0.85756327, 0.85638611, 0.85623896, 0.86035903,
#        0.8693349 , 0.87566215, 0.88125368, 0.88346086, 0.89302531,
#        0.89758682, 0.91230135, 0.9283402 , 0.93716892, 0.95276633,
#        0.96041789, 0.98263685, 0.99705709, 1.        , 0.99396704,
#        0.98278399, 0.97012949, 0.94290759, 0.90582696, 0.8852266 ,
#        0.8806651 , 0.87492643, 0.850206  , 0.84373161, 0.82828134,
#        0.83652148, 0.84284873, 0.8534432 , 0.86183049, 0.87080636,
#        0.88375515, 0.90509123, 0.92539729, 0.93908181, 0.95203061,
#        0.95953502, 0.96130077, 0.94496763, 0.94217187, 0.94379046,
#        0.94290759, 0.92363155, 0.91553855, 0.89582107, 0.88802237,
#        0.88537375, 0.86580341, 0.85844614, 0.85005886, 0.84961742,
#        0.84917599, 0.84829311, 0.85035315, 0.8534432 , 0.86433196,
#        0.88537375, 0.9027369 , 0.9218658 , 0.94599765, 0.96027075,
#        0.96806945, 0.93246027, 0.92525015, 0.9283402 , 0.92848735,
#        0.92554444, 0.90450265, 0.88949382, 0.87124779, 0.86683343,
#        0.86756916, 0.87448499, 0.88037081, 0.88419659, 0.88655091,
#        0.88743378, 0.87154208, 0.87639788, 0.89376104])

# %%
print(X_train.shape), print(y_train.shape)
# Out:
# (424, 100)
# (424,)
# (None, None)

# %% [markdown]
# # LSTM

# %%
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
from tensorflow.keras.models import Sequential

from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 5s 203ms/step - loss: 0.1521 - val_loss: 0.0826
# Epoch 2/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0345 - val_loss: 0.0184
# Epoch 3/100
# 7/7 [==============================] - 1s 89ms/step - loss: 0.0232 - val_loss: 0.0039
# Epoch 4/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0124 - val_loss: 0.0098
# Epoch 5/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0081 - val_loss: 0.0046
# Epoch 6/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0081 - val_loss: 0.0043
# Epoch 7/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0072 - val_loss: 0.0035
# Epoch 8/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0064 - val_loss: 0.0031
# Epoch 9/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0060 - val_loss: 0.0037
# Epoch 10/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0058 - val_loss: 0.0030
# Epoch 11/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0057 - val_loss: 0.0035
# Epoch 12/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0057 - val_loss: 0.0030
# Epoch 13/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0055 - val_loss: 0.0031
# Epoch 14/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0053 - val_loss: 0.0028
# Epoch 15/100
# 7/7 [==============================] - 1s 82ms/step - loss: 0.0053 - val_loss: 0.0030
# Epoch 16/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0052 - val_loss: 0.0027
# Epoch 17/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0051 - val_loss: 0.0028
# Epoch 18/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0049 - val_loss: 0.0026
# Epoch 19/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0050 - val_loss: 0.0031
# Epoch 20/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0050 - val_loss: 0.0026
# Epoch 21/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0047 - val_loss: 0.0029
# Epoch 22/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0047 - val_loss: 0.0024
# Epoch 23/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0045 - val_loss: 0.0023
# Epoch 24/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0043 - val_loss: 0.0023
# Epoch 25/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0043 - val_loss: 0.0022
# Epoch 26/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0042 - val_loss: 0.0022
# Epoch 27/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0040 - val_loss: 0.0022
# Epoch 28/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0039 - val_loss: 0.0021
# Epoch 29/100
# 7/7 [==============================] - 1s 89ms/step - loss: 0.0040 - val_loss: 0.0022
# Epoch 30/100
# 7/7 [==============================] - 1s 91ms/step - loss: 0.0037 - val_loss: 0.0019
# Epoch 31/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0036 - val_loss: 0.0019
# Epoch 32/100
# 7/7 [==============================] - 1s 82ms/step - loss: 0.0035 - val_loss: 0.0020
# Epoch 33/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0034 - val_loss: 0.0020
# Epoch 34/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0035 - val_loss: 0.0022
# Epoch 35/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0033 - val_loss: 0.0017
# Epoch 36/100
# 7/7 [==============================] - 1s 88ms/step - loss: 0.0032 - val_loss: 0.0017
# Epoch 37/100
# 7/7 [==============================] - 1s 82ms/step - loss: 0.0033 - val_loss: 0.0016
# Epoch 38/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0030 - val_loss: 0.0016
# Epoch 39/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0031 - val_loss: 0.0016
# Epoch 40/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0029 - val_loss: 0.0017
# Epoch 41/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0029 - val_loss: 0.0017
# Epoch 42/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0030 - val_loss: 0.0019
# Epoch 43/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0027 - val_loss: 0.0018
# Epoch 44/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0026 - val_loss: 0.0014
# Epoch 45/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0025 - val_loss: 0.0015
# Epoch 46/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0026 - val_loss: 0.0014
# Epoch 47/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0027 - val_loss: 0.0014
# Epoch 48/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0026 - val_loss: 0.0015
# Epoch 49/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0026 - val_loss: 0.0020
# Epoch 50/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 51/100
# 7/7 [==============================] - 1s 82ms/step - loss: 0.0025 - val_loss: 0.0022
# Epoch 52/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0025 - val_loss: 0.0014
# Epoch 53/100
# 7/7 [==============================] - 1s 82ms/step - loss: 0.0021 - val_loss: 0.0013
# Epoch 54/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0021 - val_loss: 0.0013
# Epoch 55/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0021 - val_loss: 0.0012
# Epoch 56/100
# 7/7 [==============================] - 1s 82ms/step - loss: 0.0021 - val_loss: 0.0013
# Epoch 57/100
# 7/7 [==============================] - 1s 89ms/step - loss: 0.0021 - val_loss: 0.0012
# Epoch 58/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0019 - val_loss: 0.0012
# Epoch 59/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0019 - val_loss: 0.0012
# Epoch 60/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0018 - val_loss: 0.0011
# Epoch 61/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0018 - val_loss: 0.0011
# Epoch 62/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0017 - val_loss: 0.0011
# Epoch 63/100
# 7/7 [==============================] - 1s 82ms/step - loss: 0.0016 - val_loss: 0.0011
# Epoch 64/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0017 - val_loss: 0.0011
# Epoch 65/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0016 - val_loss: 0.0011
# Epoch 66/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0016 - val_loss: 0.0011
# Epoch 67/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0015 - val_loss: 0.0010
# Epoch 68/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0015 - val_loss: 0.0010
# Epoch 69/100
# 7/7 [==============================] - 1s 82ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 70/100
# 7/7 [==============================] - 1s 81ms/step - loss: 0.0014 - val_loss: 9.9217e-04
# Epoch 71/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 72/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 73/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0015 - val_loss: 9.8065e-04
# Epoch 74/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0013 - val_loss: 9.4866e-04
# Epoch 75/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 76/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0014 - val_loss: 9.3730e-04
# Epoch 77/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 78/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0013 - val_loss: 9.0698e-04
# Epoch 79/100
# 7/7 [==============================] - 1s 82ms/step - loss: 0.0013 - val_loss: 9.5894e-04
# Epoch 80/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0013 - val_loss: 0.0010
# Epoch 81/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0014 - val_loss: 9.3918e-04
# Epoch 82/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0012 - val_loss: 8.7405e-04
# Epoch 83/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0011 - val_loss: 9.2367e-04
# Epoch 84/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0012 - val_loss: 8.2852e-04
# Epoch 85/100
# 7/7 [==============================] - 1s 89ms/step - loss: 0.0011 - val_loss: 8.1530e-04
# Epoch 86/100
# 7/7 [==============================] - 1s 89ms/step - loss: 0.0011 - val_loss: 8.2064e-04
# Epoch 87/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0011 - val_loss: 7.9624e-04
# Epoch 88/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0012 - val_loss: 8.2583e-04
# Epoch 89/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 90/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0012 - val_loss: 7.7866e-04
# Epoch 91/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0011 - val_loss: 8.8967e-04
# Epoch 92/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0012 - val_loss: 7.9442e-04
# Epoch 93/100
# 7/7 [==============================] - 1s 82ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 94/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 95/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0016 - val_loss: 7.3259e-04
# Epoch 96/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0012 - val_loss: 9.9428e-04
# Epoch 97/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0011 - val_loss: 9.1306e-04
# Epoch 98/100
# 7/7 [==============================] - 1s 82ms/step - loss: 0.0011 - val_loss: 7.7376e-04
# Epoch 99/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0010 - val_loss: 9.5169e-04
# Epoch 100/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0010 - val_loss: 8.3264e-04

# %%
### Lets Do the prediction and check performance metrics
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
# Out:
# 14/14 [==============================] - 1s 15ms/step
# 6/6 [==============================] - 0s 16ms/step

# %%
##Transformback to original form
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
print('MSE_Training:', mean_squared_error(y_train,train_predict))
print('MSE_Testing:',mean_squared_error(ytest,test_predict))
# Out:
# MSE_Training: 12715.703155306828
# MSE_Testing: 13594.319102431948

# %%
### Plotting 
# shift train predictions for plotting
look_back=100
trainPredictPlot = numpy.empty_like(df4)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(df4)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df4)-1, :] = test_predict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(df4))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
df_test=pd.read_csv("test_data.csv")
df_test.head()
# Out:
#        Date  Prediction
# 0  1/1/2019         NaN
# 1  1/2/2019         NaN
# 2  1/3/2019         NaN
# 3  1/4/2019         NaN
# 4  1/5/2019         NaN

# %% [markdown]
# ## ARIMA

# %%
#!pip install --upgrade patsy
#!pip install statsmodels
#!pip install --upgrade --no-deps statsmodels

# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA
from matplotlib import pyplot as plt
from pandas import read_csv
from pandas import datetime 
from matplotlib import pyplot

from sklearn.metrics import mean_squared_error
from math import sqrt
# Out:
# C:\Users\Farzan Nawaz\AppData\Local\Temp\ipykernel_8628\4219278593.py:5: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime

# %%
df = pd.read_csv("train_data.csv")
df.head()
# Out:
#         Date  Petrol (USD)
# 0   6/9/2003         74.59
# 1  6/16/2003         74.47
# 2  6/23/2003         74.42
# 3  6/30/2003         74.35
# 4   7/7/2003         74.28

# %%
df.rename(columns={"Petrol (USD)": "Petrol"}, inplace = True)
df.head()
# Out:
#         Date  Petrol
# 0   6/9/2003   74.59
# 1  6/16/2003   74.47
# 2  6/23/2003   74.42
# 3  6/30/2003   74.35
# 4   7/7/2003   74.28

# %%
df2 = df.dropna()
df3=df2[df2.Petrol<160]
df3.head()
# Out:
#         Date  Petrol
# 0   6/9/2003   74.59
# 1  6/16/2003   74.47
# 2  6/23/2003   74.42
# 3  6/30/2003   74.35
# 4   7/7/2003   74.28

# %%
df4=df3.reset_index()['Petrol']
df4.head()
# Out:
# 0    74.59
# 1    74.47
# 2    74.42
# 3    74.35
# 4    74.28
# Name: Petrol, dtype: float64

# %%
model1 = ARIMA(df4.values, order=(5,1,0))
model_fit1 = model1.fit()
output1= model_fit1.forecast(steps=50)# Change steps value for diff no of days u want to forecast.
output1
# Out:
# array([119.80670599, 119.52143354, 119.30634698, 119.14818606,
#        119.02925494, 118.93899218, 118.87071727, 118.81917634,
#        118.78030454, 118.75097726, 118.72884029, 118.71213019,
#        118.69951766, 118.68999841, 118.68281381, 118.67739119,
#        118.6732984 , 118.67020933, 118.66787782, 118.6661181 ,
#        118.66478993, 118.66378749, 118.66303089, 118.66245983,
#        118.66202882, 118.66170352, 118.66145799, 118.66127268,
#        118.66113281, 118.66102724, 118.66094756, 118.66088743,
#        118.66084204, 118.66080778, 118.66078192, 118.66076241,
#        118.66074768, 118.66073656, 118.66072817, 118.66072184,
#        118.66071706, 118.66071345, 118.66071073, 118.66070867,
#        118.66070712, 118.66070595, 118.66070507, 118.6607044 ,
#        118.6607039 , 118.66070352])
